# %%
#os.system('source /share/home/Liaoyt/bin/env/aiqm1-env.sh')
import mlatom as ml
xyz = '/share/home/Liaoyt/GauAPIs/tmpfile/mlatomtest/gau_mlatom.xyz'
mol = ml.data.molecule.from_xyz_file(xyz)
mol.charge= -1
mol.multiplicity = 1
model = ml.models.methods(method='AIQM1',qmprog='mndo')
model.predict(molecule=mol,calculate_energy=True,calculate_energy_gradients=True)
mol.get_energy_gradients()
# Out:
# array([[ 8.98565994e-02, -9.74731632e-02, -8.47177232e-02],
#        [-8.99648929e-02,  1.17076384e-01,  1.32325393e-01],
#        [-7.81850343e-02, -8.77058778e-02,  1.94202613e-01],
#        [-2.00348806e-02,  1.86011067e-02,  1.26831360e-01],
#        [ 2.20610796e-02,  1.82390677e-02, -4.83079343e-02],
#        [ 7.38370548e-02,  3.59734705e-02, -1.39745997e-01],
#        [ 9.05527339e-02, -9.72835011e-02,  5.63824987e-02],
#        [-1.19500328e-01, -7.86222242e-02, -2.47999664e-02],
#        [-1.41152804e-02,  1.18650745e-02, -6.71760123e-02],
#        [ 9.13207229e-02,  6.82603260e-02, -1.58948258e-01],
#        [-5.64126757e-02, -6.21808672e-02,  1.23296993e-01],
#        [-1.23802217e-01, -6.94418992e-02, -4.25189818e-02],
#        [ 6.21586428e-02,  6.51072148e-02, -1.19341092e-01],
#        [-3.55401701e-02,  1.02832447e-01,  9.21804595e-02],
#        [ 5.81540232e-02,  7.15377521e-02, -1.18199701e-01],
#        [ 9.20309032e-02, -8.70764461e-02,  4.92831507e-02],
# ...
